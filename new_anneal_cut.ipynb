# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import boxcluster
from boxcluster import BoxList
from boxcluster import BoxCut
#from boxcluster.boxcut import BoxCut2
from boxcluster import BoxSort
from boxcluster.fake_data import generate_nested_data

# %%
import pandas as pd
import numpy as np

# %%
from plotting import mplot
import matplotlib.pyplot as plt

# %%
test_soln = generate_nested_data(noise=0.05)

# %%
# bc = BoxCut(test_soln)
# boxes, _ = bc.fit_boxes(test_soln)
# mplot(test_soln, boxes=boxes)
# boxes

# %%
# def timetest2():
#     bc2 = BoxCut2(test_soln)
#     best2 = bc2(save_history=False)
    
# %timeit timetest2()

# %%
bc2 = BoxCut(test_soln)
best2 = bc2(save_history=True)
mplot(test_soln, boxes=best2)
best2
# Out:
# 18
# /Users/peterwinter/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# Fit:34.1 Boxes: [3, 8, 16, 22, 23, 24, 25, 28, 31, 32, 40, 44, 48, 52, 54, 56, 63, 64]

# %%
df = pd.DataFrame(bc2.history).set_index('evals')
df.head()
# Out:
#        last_move  moves_this_temp move_accepted    temp  current_fit  \
# evals
# 0              1                0          True  0.0010    44.264842
# 1              2                0          True  0.0009    44.082137
# 2              3                0          True  0.0009    44.034973
# 3              0                0          True  0.0009    43.942840
# 4              1                0          True  0.0009    44.125766
#
#          new_fit
# evals
# 0      44.082137
# 1      44.034973
# 2      43.942840
# 3      44.125766
# 4      43.995016

# %%
df[['last_move']].plot()

# %%
df['temp'].plot()

# %%
df[['current_fit', 'new_fit']].plot()
